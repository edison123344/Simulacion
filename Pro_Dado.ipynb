# %% [markdown]
# # Probabilidad Dado

# %% [markdown]
# ### 100 lansamientos

# %%
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd
import matplotlib.pyplot as plt # importando matplotlib
import seaborn as sns

resultados = []
for lanzamientos in range(1,100):
    lanzamientos = np.random.choice([1,6], lanzamientos)+ np.random.choice([1,6], lanzamientos)
    caras = lanzamientos.mean()
    resultados.append(caras)

# graficamente
df = pd.DataFrame({ 'lanzamientos' : resultados})

df.plot(title='Ley de grandes números',color='r',figsize=(8, 6))
plt.axhline(7)
plt.xlabel("Número de lanzamientos")
plt.ylabel("frecuencia caras dado")
plt.show()

# %% [markdown]
# ### 1000 lansamientos

# %%
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd
import matplotlib.pyplot as plt # importando matplotlib
import seaborn as sns

resultados = []
for lanzamientos in range(1,1000):
    lanzamientos = np.random.choice([1,6], lanzamientos)+ np.random.choice([1,6], lanzamientos)
    caras = lanzamientos.mean()
    resultados.append(caras)

# graficamente
df = pd.DataFrame({ 'lanzamientos' : resultados})

df.plot(title='Ley de grandes números',color='r',figsize=(8, 6))
plt.axhline(7)
plt.xlabel("Número de lanzamientos")
plt.ylabel("frecuencia caras dado")
plt.show()

# %% [markdown]
# ### 10000 lanzamientos

# %%
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd
import matplotlib.pyplot as plt # importando matplotlib
import seaborn as sns

resultados = []
for lanzamientos in range(1,10000):
    lanzamientos = np.random.choice([1,6], lanzamientos)+ np.random.choice([1,6], lanzamientos)
    caras = lanzamientos.mean()
    resultados.append(caras)

# graficamente
df = pd.DataFrame({ 'lanzamientos' : resultados})

df.plot(title='Ley de grandes números',color='r',figsize=(8, 6))
plt.axhline(7)
plt.xlabel("Número de lanzamientos")
plt.ylabel("frecuencia caras dado")
plt.show()
